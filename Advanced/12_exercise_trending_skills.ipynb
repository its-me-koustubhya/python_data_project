# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast

df = pd.read_csv(r'C:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\data_jobs.csv')

# converting the job_posted_date object to datetime
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df['job_skills'] = df['job_skills'].apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 10
#       8 # converting the job_posted_date object to datetime
#       9 df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
# ---> 10 df['job_skills'] = df['job_skills'].apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[19], line 10, in <lambda>(skill)
#       8 # converting the job_posted_date object to datetime
#       9 df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
# ---> 10 df['job_skills'] = df['job_skills'].apply(lambda skill: ast.literal_eval(skill) if pd.notna(skill) else skill)
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\ast.py:92, in literal_eval.<locals>._convert(node)
#      90     return tuple(map(_convert, node.elts))
#      91 elif isinstance(node, List):
# ---> 92     return list(map(_convert, node.elts))
#      93 elif isinstance(node, Set):
#      94     return set(map(_convert, node.elts))
#
# File c:\Users\singh\Documents\DATA ANALYTICS BOOTCAMP\Anaconda\envs\python_project\Lib\ast.py:86, in literal_eval.<locals>._convert(node)
#      84             return - operand
#      85     return _convert_num(node)
# ---> 86 def _convert(node):
#      87     if isinstance(node, Constant):
#      88         return node.value
#
# KeyboardInterrupt:

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA['job_posted_month'] = df_DA['job_posted_date'].dt.strftime('%B')
df_DA_explode = df_DA.explode('job_skills')
df_DA_explode = df_DA_explode.drop(columns='job_posted_month_no')

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month', columns='job_skills', aggfunc='size', fill_value=0)

# %% [markdown]
# Creating a new index to show the total for all the column

# %%
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop('Total')
df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# April              7553   5496    4557     3776      3106  2399  2598
# August             8823   6482    5576     4533      3859  2975  2560
# December           6058   4376    4196     3139      2857  2125  1858
# February           7947   5772    4751     3936      3307  2576  2634
# January           11336   8170    6606     5596      4285  3607  3830
# July               7687   5513    4831     3928      3350  2444  2118
# June               7584   5724    4707     3812      3275  2442  2174
# March              7868   5675    4741     4051      3176  2650  2554
# May                6617   4773    4070     3245      2695  2093  1940
# November           6652   4776    4233     3284      3012  2159  1738
# October            7474   5217    4693     3709      3340  2380  2114
# September          6829   4886    4229     3446      3118  2146  1880
#
# job_skills        powerpoint  word   sap  ...  xamarin  mattermost  gtx  \
# job_posted_month                          ...
# April                   1190  1177   947  ...        0           0    0
# August                  1332  1298  1117  ...        0           0    0
# December                 822   786   753  ...        0           0    0
# February                1291  1235   954  ...        0           0    0
# January                 1880  1778  1251  ...        0           0    0
# July                    1096  1069   996  ...        0           0    1
# June                    1173  1237   987  ...        0           0    0
# March                   1266  1203   892  ...        1           0    0
# May                      979   957   851  ...        0           0    0
# November                 894   887   808  ...        0           1    0
# October                  955   990   872  ...        1           0    0
# September                944   945   852  ...        0           1    0
#
# job_skills        esquisse  chainer  capacitor  nuxt.js  msaccess  ovh  suse
# job_posted_month
# April                    0        0          0        0         0    1     0
# August                   0        0          0        0         0    0     0
# December                 0        1          0        0         0    0     0
# February                 0        0          0        0         0    0     0
# January                  0        0          1        1         0    0     0
# July                     0        0          0        0         0    0     0
# June                     0        0          0        0         0    0     0
# March                    0        0          0        0         0    0     1
# May                      0        0          0        0         1    0     0
# November                 1        0          0        0         0    0     0
# October                  0        0          0        0         0    0     0
# September                0        0          0        0         0    0     0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:, :5].plot(kind='line')
plt.title('Monthly Skill Trend')
plt.xlabel('')
plt.ylabel('Count')
plt.show()
